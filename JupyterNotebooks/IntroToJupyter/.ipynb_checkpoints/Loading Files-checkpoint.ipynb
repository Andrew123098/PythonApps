# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data.txt',
#  'Loading Files.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx']

# %%
import pandas

# %%
df1=pandas.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2=pandas.read_json("supermarkets.json")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3=pandas.read_excel("supermarkets.xlsx",sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4=pandas.read_csv("supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5=pandas.read_csv("supermarkets-semi-colons.txt",sep=";")
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6=pandas.read_json("https://pythonhow.com/supermarkets.json")
df6
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7=pandas.read_csv("data.txt")   ##This makes an incorrect header
df7
# Out:
#    1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 0  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 1  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 2  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 3  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 4  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df8=pandas.read_csv("data.txt", header = None)
df8
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df8.columns=["ID", "Address", "City", "ZIP", "Country", "Name", "Employees"]
df8
# Out:
#    ID          Address           City               ZIP Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
#How to assign an index to your values
df8.set_index("ID")
df8
# Out:
#    ID          Address           City               ZIP Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df8.set_index("Name",inplace=True, drop=False)
df8
# Out:
#              ID          Address           City               ZIP Country  \
# Name
#  Madeira      1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119     USA
# Super River   3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       5  1056 Sanchez St  San Francisco        California     USA
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees
# Name
#  Madeira         Madeira          8
# Bready Shop  Bready Shop         15
# Super River  Super River         25
# Ben's Shop    Ben's Shop         10
# Sanchez          Sanchez         12
# Richvalley    Richvalley         20

# %%
#Location based indexing
df8.loc["Bready Shop":"Super River","ID":"Country"]
# Out:
#              ID         Address           City               ZIP Country
# Name
# Bready Shop   2  735 Dolores St  San Francisco          CA 94119     USA
# Super River   3     332 Hill St  San Francisco  California 94114     USA

# %%
list(df8.loc["Bready Shop":"Super River", "Country"])
# Out:
# ['USA', 'USA']

# %%
list(df8.loc[:,"Name"])
# Out:
# [' Madeira',
#  'Bready Shop',
#  'Super River',
#  "Ben's Shop",
#  'Sanchez',
#  'Richvalley']

# %%
df8.iloc[0:3,:]
# Out:
#              ID         Address           City               ZIP Country  \
# Name
#  Madeira      1    3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   2  735 Dolores St  San Francisco          CA 94119     USA
# Super River   3     332 Hill St  San Francisco  California 94114     USA
#
#                     Name  Employees
# Name
#  Madeira         Madeira          8
# Bready Shop  Bready Shop         15
# Super River  Super River         25

# %%
#Deleting items and columns from a data frame
df8.drop("ID",1)
# Out:
#                      Address           City               ZIP Country  \
# Name
#  Madeira        3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   735 Dolores St  San Francisco          CA 94119     USA
# Super River      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop      3995 23rd St  San Francisco          CA 94114     USA
# Sanchez      1056 Sanchez St  San Francisco        California     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees
# Name
#  Madeira         Madeira          8
# Bready Shop  Bready Shop         15
# Super River  Super River         25
# Ben's Shop    Ben's Shop         10
# Sanchez          Sanchez         12
# Richvalley    Richvalley         20

# %%
df8.drop(df8.columns[0:3],1)
# Out:
#                           ZIP Country         Name  Employees
# Name
#  Madeira             CA 94114     USA      Madeira          8
# Bready Shop          CA 94119     USA  Bready Shop         15
# Super River  California 94114     USA  Super River         25
# Ben's Shop           CA 94114     USA   Ben's Shop         10
# Sanchez            California     USA      Sanchez         12
# Richvalley           CA 94114     USA   Richvalley         20

# %%
#How to add  NEW COLUMN
len(df8.index)
# Out:
# 6

# %%
df8.shape
# Out:
# (6, 7)

# %%
df8.shape[0]
# Out:
# 6

# %%
df8["Continent"]=df8.shape[0]*["North America"]

# %%
df8
# Out:
#              ID          Address           City               ZIP Country  \
# Name
#  Madeira      1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119     USA
# Super River   3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       5  1056 Sanchez St  San Francisco        California     USA
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees      Continent
# Name
#  Madeira         Madeira          8  North America
# Bready Shop  Bready Shop         15  North America
# Super River  Super River         25  North America
# Ben's Shop    Ben's Shop         10  North America
# Sanchez          Sanchez         12  North America
# Richvalley    Richvalley         20  North America

# %%
df8["Continent"]=df8["Country"]+", "+"North America"

# %%
df8
# Out:
#              ID          Address           City               ZIP Country  \
# Name
#  Madeira      1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119     USA
# Super River   3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       5  1056 Sanchez St  San Francisco        California     USA
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees           Continent
# Name
#  Madeira         Madeira          8  USA, North America
# Bready Shop  Bready Shop         15  USA, North America
# Super River  Super River         25  USA, North America
# Ben's Shop    Ben's Shop         10  USA, North America
# Sanchez          Sanchez         12  USA, North America
# Richvalley    Richvalley         20  USA, North America

# %%
#How to add a NEW ROW (.T means Transpose (like from linear algebra))
df8_t=df8.T

# %%
df8_t
# Out:
# Name                  Madeira         Bready Shop         Super River  \
# ID                          1                   2                   3
# Address          3666 21st St      735 Dolores St         332 Hill St
# City            San Francisco       San Francisco       San Francisco
# ZIP                  CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
# Name               Ben's Shop             Sanchez          Richvalley
# ID                          4                   5                   6
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# ...

# %%
df8_t["My Address"]=["My ID","My City", "My Country", 10, 7, "My Shop", "My State", "My Continent"]

# %%
df8_t
# Out:
# Name                  Madeira         Bready Shop         Super River  \
# ID                          1                   2                   3
# Address          3666 21st St      735 Dolores St         332 Hill St
# City            San Francisco       San Francisco       San Francisco
# ZIP                  CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
# Name               Ben's Shop             Sanchez          Richvalley  \
# ID                          4                   5                   6
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# ...

# %%
df8=df8_t.T

# %%
df8
# Out:
#                 ID          Address           City               ZIP Country  \
# Name
#  Madeira         1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop      2   735 Dolores St  San Francisco          CA 94119     USA
# Super River      3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop       4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez          5  1056 Sanchez St  San Francisco        California     USA
# Richvalley       6  551 Alvarado St  San Francisco          CA 94114     USA
# My Address   My ID          My City     My Country                10       7
#
#                     Name Employees           Continent
# Name
#  Madeira         Madeira         8  USA, North America
# Bready Shop  Bready Shop        15  USA, North America
# Super River  Super River        25  USA, North America
# Ben's Shop    Ben's Shop        10  USA, North America
# Sanchez          Sanchez        12  USA, North America
# ...

# %%
type(df8)
# Out:
# pandas.core.frame.DataFrame

# %%
#GEOCODING ADDESSES WITH PANDAS AND GEOPY
import geopy
dir(geopy)
# Out:
# ['AlgoliaPlaces',
#  'ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'BaiduV3',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'MapQuest',
#  'MapTiler',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
from geopy.geocoders import ArcGIS

# %%
nom = ArcGIS()

# %%
nom.geocode("3995 23rd St, San Francisco, CA 94114")
# Out:
# Location(3995 23rd St, San Francisco, California, 94114, (37.752990821253434, -122.43170235858965, 0.0))

# %%
#If you put in the wrong address, the closest similar address or general area will be used in its place
n=nom.geocode("4930 Sharynne Ln, Tampa Bay, FL 90274")
print(n)
# Out:
# Bay County, Florida

# %%
n=nom.geocode("4930 Sharynne Lane")
print(n)
# Out:
# 4930 Sharynne Ln, Torrance, California, 90505

# %%
n.longitude
# Out:
# -118.36744725437129

# %%
n.latitude
# Out:
# 33.81993869773226

# %%
#Lets create a Latitude and Longitude Column in the Chart

# %%
import pandas

# %%
df=pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
#make column with complete addresses
df["Address"]=df["Address"]+","+df["City"]+","+df["State"]+","+df["Country"]
df
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 1   2  735 Dolores St,San Francisco,CA 94119,USA,San ...  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114,USA...  San Francisco
# 3   4  3995 23rd St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 4   5  1056 Sanchez St,San Francisco,California,USA,S...  San Francisco
# 5   6  551 Alvarado St,San Francisco,CA 94114,USA,San...  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"]=df["Address"].apply(nom.geocode)
df
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 1   2  735 Dolores St,San Francisco,CA 94119,USA,San ...  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114,USA...  San Francisco
# 3   4  3995 23rd St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 4   5  1056 Sanchez St,San Francisco,California,USA,S...  San Francisco
# 5   6  551 Alvarado St,San Francisco,CA 94114,USA,San...  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates
# ...

# %%
df.Coordinates[0].latitude
# Out:
# 37.7564496899993

# %%
df["Latitude"]=df["Coordinates"].apply(lambda x: x.latitude)
df["Longitude"]=df["Coordinates"].apply(lambda y: y.longitude)
df
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 1   2  735 Dolores St,San Francisco,CA 94119,USA,San ...  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114,USA...  San Francisco
# 3   4  3995 23rd St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 4   5  1056 Sanchez St,San Francisco,California,USA,S...  San Francisco
# 5   6  551 Alvarado St,San Francisco,CA 94114,USA,San...  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...
